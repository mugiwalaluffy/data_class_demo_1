# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# ================================================================================
# Prepare data
# ================================================================================

# Load the data
data_dir = os.path.abspath("../data/")
data_file = os.path.abspath(data_dir + "/sales_2012_2014.csv")
df = pd.read_csv(data_file)

# Show how the first few rows of the data frame look like
print(df.head())
# Out:
#   Retailer country Order method type  Retailer type       Product line  \
# 0    United States               Fax  Outdoors Shop  Camping Equipment
# 1    United States               Fax  Outdoors Shop  Camping Equipment
# 2    United States               Fax  Outdoors Shop  Camping Equipment
# 3    United States               Fax  Outdoors Shop  Camping Equipment
# 4    United States               Fax  Outdoors Shop  Camping Equipment
#
#     Product type                    Product  Year  Quarter    Revenue  \
# 0   Cooking Gear  TrailChef Deluxe Cook Set  2012  Q1 2012   59628.66
# 1   Cooking Gear     TrailChef Double Flame  2012  Q1 2012   35950.32
# 2          Tents                  Star Dome  2012  Q1 2012   89940.48
# 3          Tents               Star Gazer 2  2012  Q1 2012  165883.41
# 4  Sleeping Bags            Hibernator Lite  2012  Q1 2012  119822.20
#
#    Quantity  Gross margin
# 0       489      0.347548
# 1       252      0.474274
# 2       147      0.352772
# 3       303      0.282938
# 4      1415      0.291450

# %%
secname = "Revenue per retailer country from 2012 to 2014."

table = pd.pivot_table(df, values='Revenue', index=['Retailer country'], aggfunc=np.sum)
print(table)

plt.rcParams.update({'font.size': 24})
ax = table.plot.barh(subplots='True', figsize=(7,11))
plt.title(secname)
plt.show()
ax[0].get_figure().savefig('../images/revenue_country.png', bbox_inches='tight')
plt.close()
# Out:
#                        Revenue
# Retailer country
# Australia         1.093000e+08
# Austria           1.133666e+08
# Belgium           9.695857e+07
# Brazil            1.090657e+08
# Canada            2.468877e+08
# China             2.488232e+08
# Denmark           4.789853e+07
# Finland           1.522220e+08
# France            2.195236e+08
# Germany           2.007737e+08
# Italy             1.546308e+08
# Japan             2.816655e+08
# Korea             1.585741e+08
# Mexico            1.393696e+08
# Netherlands       1.489364e+08
# Singapore         1.562618e+08
# Spain             1.367638e+08
# Sweden            8.063553e+07
# Switzerland       1.007319e+08
# United Kingdom    2.192231e+08
# United States     6.508110e+08

# %%
secname = "Revenue per retailer type from 2012 to 2014."

table = pd.pivot_table(df, values='Revenue', index=['Retailer type'], aggfunc=np.sum)
print(table)

plt.rcParams.update({'font.size': 18})
ax = table.plot.pie(subplots='True', figsize=(15,15))
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.01),  shadow=True, ncol=2)
plt.title(secname)
plt.show()
ax[0].get_figure().savefig('../images/revenue_retailertype.png', bbox_inches='tight')
plt.close()
# Out:
#                              Revenue
# Retailer type
# Department Store        6.624457e+08
# Direct Marketing        5.436708e+07
# Equipment Rental Store  4.343419e+07
# Eyewear Store           1.717182e+08
# Golf Shop               4.108702e+08
# Outdoors Shop           1.267371e+09
# Sports Store            9.698808e+08
# Warehouse Store         1.923362e+08

# %%
secname = "Revenue per order method type from 2012 to 2014."

table = pd.pivot_table(df, values='Revenue', index=['Order method type'], aggfunc=np.sum)
print(table)

plt.rcParams.update({'font.size': 24})
ax = table.plot.pie(subplots='True', figsize=(11,11))
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.01),  shadow=True, ncol=2)
plt.title(secname)
plt.show()
ax[0].get_figure().savefig('../images/revenue_ordermethodtype.png', bbox_inches='tight')
plt.close()
# Out:
#                         Revenue
# Order method type
# E-mail             8.444025e+07
# Fax                4.143407e+07
# Mail               2.332449e+07
# Sales visit        2.091221e+08
# Special            1.344540e+07
# Telephone          1.621922e+08
# Web                3.238464e+09

# %%
secname = "Revenue per product type in 2012"

df1 = df[df['Year'] == 2012]
table = pd.pivot_table(df1, values='Revenue', index=['Product type'], aggfunc=np.sum)
print(table)

plt.rcParams.update({'font.size': 24})
ax = table.plot.barh(figsize=(7,11))
plt.title(secname)
plt.show()
ax.get_figure().savefig('../images/revenue_producttype_2012.png', bbox_inches='tight')
plt.close()
# Out:
#                            Revenue
# Product type
# Binoculars            3.031057e+07
# Climbing Accessories  2.187649e+07
# Cooking Gear          7.084313e+07
# Eyewear               2.086486e+08
# First Aid             2.890457e+06
# Golf Accessories      1.325177e+07
# Insect Repellents     1.157943e+07
# Irons                 5.511658e+07
# Knives                3.316418e+07
# Lanterns              2.978892e+07
# Navigation            4.372457e+07
# Packs                 8.741676e+07
# Putters               2.892325e+07
# Rope                  2.865527e+07
# Safety                2.250587e+07
# Sleeping Bags         7.703848e+07
# Sunscreen             1.053868e+07
# Tents                 1.376703e+08
# Tools                 3.406203e+07
# Watches               1.404754e+08
# Woods                 7.071483e+07
